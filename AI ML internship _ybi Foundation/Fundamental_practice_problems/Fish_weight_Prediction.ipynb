# %%
import pandas as pd

# %%
dataset = pd.read_csv('https://github.com/Poorani-27/AI-ML/raw/main/Dataset/Fish.csv')
dataset
# Out:
#      Category Species  Weight   Height   Width  Length1  Length2  Length3
# 0           1   Bream   242.0  11.5200  4.0200     23.2     25.4     30.0
# 1           1   Bream   290.0  12.4800  4.3056     24.0     26.3     31.2
# 2           1   Bream   340.0  12.3778  4.6961     23.9     26.5     31.1
# 3           1   Bream   363.0  12.7300  4.4555     26.3     29.0     33.5
# 4           1   Bream   430.0  12.4440  5.1340     26.5     29.0     34.0
# ..        ...     ...     ...      ...     ...      ...      ...      ...
# 154         6   Smelt    12.2   2.0904  1.3936     11.5     12.2     13.4
# 155         6   Smelt    13.4   2.4300  1.2690     11.7     12.4     13.5
# 156         6   Smelt    12.2   2.2770  1.2558     12.1     13.0     13.8
# 157         6   Smelt    19.7   2.8728  2.0672     13.2     14.3     15.2
# 158         6   Smelt    19.9   2.9322  1.8792     13.8     15.0     16.2
#
# [159 rows x 8 columns]

# %%
dataset.columns
# Out:
# Index(['Category', 'Species', 'Weight', 'Height', 'Width', 'Length1',
#        'Length2', 'Length3'],
#       dtype='object')

# %%
y = dataset['Weight']
x = dataset[['Category', 'Height', 'Width', 'Length1',
       'Length2', 'Length3']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=2529)

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      Category   Height   Width  Length1  Length2  Length3
# 6           1  14.1795  5.2785     26.8     29.7     34.5
# 54          5   9.4850  5.3550     29.5     31.7     35.0
# 80          3   5.1376  3.0368     17.8     19.6     20.8
# 138         4   7.7920  4.8700     43.2     46.0     48.7
# 91          3   5.8560  3.6240     20.5     22.5     24.0
# 48          5   7.5344  3.8352     22.0     24.0     27.2
# 52          5   8.8768  4.4968     24.0     26.0     29.2
# 103         3   7.1672  4.3350     25.4     27.5     28.9
# 57          7   8.7780  4.6816     25.6     28.0     30.8
# 149         6   2.0832  1.2772     10.7     11.2     12.4
# 153         6   2.2044  1.1484     11.4     12.0     13.2
# 108         3   7.6156  4.7716     27.8     30.0     31.6
# 90          3   5.5225  3.9950     20.0     22.0     23.5
# 118         3  12.4313  7.3514     36.6     39.0     41.3
# 131         4   6.2884  4.0198     34.8     37.3     39.8
# ...

# %%
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error,  mean_squared_error

# %%
mae=mean_absolute_error(y_test,y_predict)
print("Mean Absolute Error : ",mae)
mae=mean_absolute_percentage_error(y_test,y_predict)
print("Mean Absolute percentage Error : ",mae)
mae=mean_squared_error(y_test,y_predict)
print("Mean squared Error : ",mae)
# Out:
# Mean Absolute Error :  107.73909506521207
# Mean Absolute percentage Error :  2.339914978089575
# Mean squared Error :  18109.617559195533

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_predict)
print("R-squared Score: ", r2)
# Out:
# R-squared Score:  0.8170610501815971

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_predict, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)  # Plotting the diagonal line
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted')
plt.show()
