# %% [markdown]
# Import library

# %%
import pandas as pd

# %% [markdown]
# import or read data

# %%
salary = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/a6bcba4b6f9b87d8f924df1dacad300785571cfe/Salary%20Data.csv')

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
salary.tail()
# Out:
#     Experience Years  Salary
# 35               9.0  105582
# 36               9.5  116969
# 37               9.6  112635
# 38              10.3  122391
# 39              10.5  121872

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
salary.shape
# Out:
# (40, 2)

# %% [markdown]
# Setp3 : define target Y and features X

# %%
y=salary['Salary']
x=salary[['Experience Years']]

# %% [markdown]
# y dependent [], x independent [[]]

# %% [markdown]
# step4:train , test, split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((30, 1), (10, 1), (30,), (10,))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=2456)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %%
x_train
# Out:
#     Experience Years
# 16               4.0
# 3                1.5
# 31               7.9
# 36               9.5
# 6                2.5
# 32               8.2
# 22               5.1
# 28               6.5
# 30               7.1
# 33               8.5
# 0                1.1
# 27               6.2
# 18               4.3
# 14               3.9
# 39              10.5
# 1                1.2
# 2                1.3
# 25               5.9
# 26               6.0
# 29               6.8
# 35               9.0
# 19               4.5
# 11               3.5
# 10               3.2
# 13               3.8
# 8                3.0
# 24               5.5
# 5                2.2

# %%
x_test
# Out:
#     Experience Years
# 9                3.2
# 38              10.3
# 4                2.0
# 21               4.9
# 7                2.9
# 23               5.3
# 12               3.7
# 20               4.7
# 37               9.6
# 17               4.1
# 34               8.7
# 15               4.0

# %%
y_test
# Out:
# 9      54445
# 38    122391
# 4      43525
# 21     67938
# 7      56642
# 23     83088
# 12     57189
# 20     64500
# 37    112635
# 17     57081
# 34    109431
# 15     55794
# Name: Salary, dtype: int64

# %%
y_train
# Out:
# 16     56957
# 3      37731
# 31    101302
# 36    116969
# 6      48266
# 32    113812
# 22     66029
# 28     90000
# 30     98273
# 33    111620
# 0      39343
# 27     91000
# 18     59095
# 14     63218
# 39    121872
# 1      42774
# 2      46205
# 25     81363
# 26     93940
# 29     91738
# 35    105582
# 19     61111
# 11     60000
# 10     64445
# 13     60200
# 8      60150
# 24     82200
# 5      39891
# Name: Salary, dtype: int64
